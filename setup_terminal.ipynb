# %% [markdown]
# # 🛠️ Configuración de la Terminal (Para que todos tengamos la misma)
#
# Uno de los problemas más comunes al aprender programación es que los comandos de **Windows** son diferentes a los de **Mac** y **Linux**.
#
# Para evitar confusiones en clase y que todos sigamos las mismas instrucciones, vamos a unificar nuestros entornos.
#
# ---

# %% [markdown]
# ## 🍎 Usuarios de Mac o Linux
#
# **¡Buenas noticias! No tenéis que hacer NADA.**
#
# Vuestra terminal por defecto (zsh o bash) ya es perfecta para la clase. Podéis relajaros 5 minutos mientras vuestros compañeros de Windows configuran su equipo.
#
# ---

# %% [markdown]
# ## 🪟 Usuarios de Windows
#
# La terminal que viene con Windows (PowerShell o CMD) usa comandos un poco antiguos y diferentes. Para tener la misma potencia que Linux/Mac, instalaremos una herramienta estándar llamada **Git Bash**.
#
# ### Paso 1: Instalación (5 min)
# 1.  Entra en **[git-scm.com/download/win](https://git-scm.com/download/win)**.
# 2.  Haz clic en **"Click here to download"** para descargar el instalador.
# 3.  Ejecuta el archivo descargado.
# 4.  ⚠️ **IMPORTANTE:** Dale a **"Next" (Siguiente)** a todas las opciones. No cambies nada. La configuración por defecto es perfecta.
# 5.  Espera a que termine y cierra el instalador.

# %% [markdown]
# ### Paso 2: Conectar VS Code con Git Bash
#
# Ahora haremos que VS Code use esta nueva terminal por defecto.
#
# 1.  Abre **Visual Studio Code**.
# 2.  Presiona las teclas `Ctrl` + `Shift` + `P` (esto abre la "Paleta de Comandos").
# 3.  Escribe y selecciona: **`Terminal: Select Default Profile`** (o *Seleccionar perfil predeterminado*).
# 4.  En la lista que aparece, busca y selecciona **`Git Bash`**.
# 5.  Ahora, **cierra la terminal actual** (clic en el icono de la papelera 🗑️) y abre una nueva con `Ctrl` + `ñ`.
#
# 🎉 **¡Listo!** Deberías ver letras de colores (verde/azul/amarillo) y el símbolo `$` al final de la línea. Ya tienes una terminal profesional.

# %% [markdown]
# ---

# %% [markdown]
# ## 🚑 Plan B: "No puedo instalar nada en este ordenador"
#
# Si estás en un ordenador del trabajo o escuela bloqueado y no puedes instalar Git Bash, usa **PowerShell**, pero ten en cuenta esta tabla de traducción:
#
# | Acción | Comando del Profesor (Linux/Mac) | Tu comando en PowerShell (Win) |
# | :--- | :--- | :--- |
# | Listar archivos | `ls` | `ls` (funciona igual) |
# | Listar (detalles) | `ls -l` | *No funciona* (usa solo `ls`) |
# | Borrar archivo | `rm archivo.txt` | `rm archivo.txt` (funciona igual) |
# | Crear archivo vacío | `touch archivo.txt` | ⚠️ Error. (Créalo con clic derecho en VS Code) |
# | Limpiar pantalla | `clear` | `clear` o `cls` |
# | Ver dónde estoy | `pwd` | `pwd` |
